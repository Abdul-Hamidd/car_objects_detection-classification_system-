# %%
# This is the Ultralytics library which runs YOLO models.
# !pip install ultralytics

# These are Python's built-in libraries for managing files and folders.
import os
import shutil
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.7 MB/s eta 0:00:00
# ...

# %%
#!rm -rf /content/drive/*
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""from ultralytics import YOLO
import os
import shutil

# ================================
# Step 1: Load YOLOv8 base model
# ================================
# 'yolov8s.pt' is the small version of YOLOv8 — good balance of speed and accuracy.
# Other options:
# - yolov8n.pt → fastest but least accurate
# - yolov8m.pt / yolov8l.pt → more accurate but slower
model = YOLO("yolov8s.pt")

# ================================
# Step 2: Train model on custom dataset
# ================================
model.train(
    data="/content/drive/MyDrive/ObjDetectionmodel/processed_dataset/dataset.yml",  # Path to your custom .yaml config file
    epochs=300,         # Number of training epochs (recommended: 100–300 for good results)
    imgsz=640,          # Image size used for training (default 640x640)
    batch=20,           # Batch size — adjust according to available GPU memory
    project="/content/drive/MyDrive/ObjDetectionmodel/best_model",  # Directory to save trained model and logs
    device="cuda",      # Use GPU (e.g., Tesla T4) for faster training
    half=True,          # Use half precision (float16) for speed and lower memory usage on GPU
    workers=8,          # Number of parallel workers for data loading
    cache=True          # Store dataset in memory to speed up training (if RAM allows)
)

# ================================
# Final Step: Training complete
# ================================
print("training complete.")"""
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.196 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
